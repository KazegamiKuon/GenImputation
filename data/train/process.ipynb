# %%
import sys
sys.path.insert(1,'../../')
from lib.data_processing import process_input as pi
from lib.config.config_class import page_config
import pandas as pd
import numpy as np

# %% [markdown]
# # Create train legend file

# %%
hap_file = '/home/cuong/VBDI/HungProject/GenImputation/data/interim/G1K_chr20_hg38_true.hap.gz'
legend_file = '/home/cuong/VBDI/HungProject/GenImputation/data/interim/G1K_chr20_hg38_true.legend.gz'
output_folder = '/home/cuong/VBDI/HungProject/GenImputation/data/train'
default_config = '/home/cuong/VBDI/HungProject/GenImputation/data/external/region_default_config.json'
num_regions = 100
concat_width = 0.2

# %%
legend_region_folder = pi.legend_to_region(legend_file,hap_file,num_regions,concat_width,True,output_folder=output_folder)
# Out:
# 0     273
# 16    301
# 32    243
# 48    175
# 64    194
#      ...
# 31    234
# 47    164
# 63    223
# 79    255
# 95    170
# Name: bin, Length: 99, dtype: int64
# Min number observe:  8
#
# Max number observe:  519
#
# Mean number observe:  227.73737373737373
#
# Info about number variant and number bin each variant
#
#    nb variants  nb bin
# 0        18174       8
# 1        18175      92
# Agree to div bin by this? [y/n]
# ...
# process region 99:   0%|          | 0/18175 [00:00<?, ?it/s]

# %%
pi.make_region_config(legend_region_folder,default_config)
# Out:
# make region config:   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# # Create train nlp file

# %%
vcf_inter_files = None
manifest_file = '../raw/infiniumomni2-5-8v1-5-a1.csv.gz'
hg_refgenome = '../data/raw/hg19.fa.gz'

# %% [markdown]
# ## ~2048 length

# %%
vcf_file_g1k_train = './G1K_22_hs37d5_biallelic_train.vcf.gz'
nlp_train_prefix = './electra_G1K_22_hs37d5/corpus_dir/G1K_22_hs37d5_biallelic_train'

# %%
pi.process_vcf_to_page_nlp(vcf_file_g1k_train,vcf_inter_files,0,nlp_train_prefix,543,9,manifest_file,hg_refgenome)

# %% [markdown]
# ## Create train nlp file base on paper compare

# %%
vcf_file_g1k_train = './G1K_22_hs37d5_biallelic_train.vcf.gz'
nlp_train_prefix = './electra_G1K_22_hs37d5/corpus_dir/G1K_22_hs37d5_biallelic_train'
region_info = '/client/user1/cuongdev/GenImputation/data/external/region_info'
region_paths = page_config.get_file_paths_in_dir(region_info,page_config.variant)
region_paths.sort()

# %%
pi.process_vcf_to_page_nlp(
            vcf_file=vcf_file_g1k_train,
            inter_vcfs=vcf_inter_files,
            af_source=0,
            ouput_prefix=nlp_train_prefix,
            regions=region_paths,
            batchs=9            
        )
# Out:
# Creating .variant.gz file!
# Load variant data!
# Done!
# Create region data:   0%|          | 0/329 [00:00<?, ?it/s]
# Region 0 cant matching 57 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 1 cant matching 59 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 2 cant matching 62 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 3 cant matching 64 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 4 cant matching 78 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 5 cant matching 60 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 6 cant matching 56 position data
# ...
# vcf genotype data to page file::   0%|          | 0/534 [00:00<?, ?it/s]
# Region 7 cant matching 58 position data
# ...
